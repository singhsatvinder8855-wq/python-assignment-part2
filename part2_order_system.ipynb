# %%
menu = {
    "Paneer Tikka":   {"category": "Starters",  "price": 180.0, "available": True},
    "Chicken Wings":  {"category": "Starters",  "price": 220.0, "available": False},
    "Veg Soup":       {"category": "Starters",  "price": 120.0, "available": True},
    "Butter Chicken": {"category": "Mains",     "price": 320.0, "available": True},
    "Dal Tadka":      {"category": "Mains",     "price": 180.0, "available": True},
    "Veg Biryani":    {"category": "Mains",     "price": 250.0, "available": True},
    "Garlic Naan":    {"category": "Mains",     "price":  40.0, "available": True},
    "Gulab Jamun":    {"category": "Desserts",  "price":  90.0, "available": True},
    "Rasgulla":       {"category": "Desserts",  "price":  80.0, "available": True},
    "Ice Cream":      {"category": "Desserts",  "price": 110.0, "available": False},
}

inventory = {
    "Paneer Tikka":   {"stock": 10, "reorder_level": 3},
    "Chicken Wings":  {"stock":  8, "reorder_level": 2},
    "Veg Soup":       {"stock": 15, "reorder_level": 5},
    "Butter Chicken": {"stock": 12, "reorder_level": 4},
    "Dal Tadka":      {"stock": 20, "reorder_level": 5},
    "Veg Biryani":    {"stock":  6, "reorder_level": 3},
    "Garlic Naan":    {"stock": 30, "reorder_level": 10},
    "Gulab Jamun":    {"stock":  5, "reorder_level": 2},
    "Rasgulla":       {"stock":  4, "reorder_level": 3},
    "Ice Cream":      {"stock":  7, "reorder_level": 4},
}

sales_log = {
    "2025-01-01": [
        {"order_id": 1,  "items": ["Paneer Tikka", "Garlic Naan"],          "total": 220.0},
        {"order_id": 2,  "items": ["Gulab Jamun", "Veg Soup"],              "total": 210.0},
        {"order_id": 3,  "items": ["Butter Chicken", "Garlic Naan"],        "total": 360.0},
    ],
    "2025-01-02": [
        {"order_id": 4,  "items": ["Dal Tadka", "Garlic Naan"],             "total": 220.0},
        {"order_id": 5,  "items": ["Veg Biryani", "Gulab Jamun"],           "total": 340.0},
    ],
    "2025-01-03": [
        {"order_id": 6,  "items": ["Paneer Tikka", "Rasgulla"],             "total": 260.0},
        {"order_id": 7,  "items": ["Butter Chicken", "Veg Biryani"],        "total": 570.0},
        {"order_id": 8,  "items": ["Garlic Naan", "Gulab Jamun"],           "total": 130.0},
    ],
    "2025-01-04": [
        {"order_id": 9,  "items": ["Dal Tadka", "Garlic Naan", "Rasgulla"], "total": 300.0},
        {"order_id": 10, "items": ["Paneer Tikka", "Gulab Jamun"],          "total": 270.0},
    ],
}

import copy

# %%
menu = {
    "Paneer Tikka":   {"category": "Starters",  "price": 180.0, "available": True},
    "Chicken Wings":  {"category": "Starters",  "price": 220.0, "available": False},
    "Veg Soup":       {"category": "Starters",  "price": 120.0, "available": True},
    "Butter Chicken": {"category": "Mains",     "price": 320.0, "available": True},
    "Dal Tadka":      {"category": "Mains",     "price": 180.0, "available": True},
    "Veg Biryani":    {"category": "Mains",     "price": 250.0, "available": True},
    "Garlic Naan":    {"category": "Mains",     "price":  40.0, "available": True},
    "Gulab Jamun":    {"category": "Desserts",  "price":  90.0, "available": True},
    "Rasgulla":       {"category": "Desserts",  "price":  80.0, "available": True},
    "Ice Cream":      {"category": "Desserts",  "price": 110.0, "available": False},
}

# ----- Task 1 : Menu Exploration -----

categories = ["Starters", "Mains", "Desserts"]

# Loop through the each category

for category in categories:
    print("\n-----", category, "-----")
    
    # Loop through the menu Food Items
    for food_items in menu:
        if menu[food_items]["category"] == category:
            price = menu[food_items]["price"]
            available = menu[food_items]["available"]
            
            if available:
                Status = "Available"
            else:
                Status = "Not Available"
                
            print(food_items.ljust(15), "Rs.", format(price, ".2f"), " - ", Status)
    print()
# Out:
# ----- Starters -----
# Paneer Tikka    Rs. 180.00  -  Available
# Chicken Wings   Rs. 220.00  -  Not Available
# Veg Soup        Rs. 120.00  -  Available
#
#
# ----- Mains -----
# Butter Chicken  Rs. 320.00  -  Available
# Dal Tadka       Rs. 180.00  -  Available
# Veg Biryani     Rs. 250.00  -  Available
# Garlic Naan     Rs. 40.00  -  Available
#
#
# ----- Desserts -----
# Gulab Jamun     Rs. 90.00  -  Available
# Rasgulla        Rs. 80.00  -  Available
# Ice Cream       Rs. 110.00  -  Not Available

# %%
# Total and available Food count
total_food_items = len(menu)
available_count = 0

for food_items in menu:
    if menu[food_items]["available"]:
        available_count += 1
print("\n ----- Total Food Items in the Menu -----")
print("Total Menu Food Items : ", total_food_items)
print("Available Menu Food Items : ", available_count)

# Most Expensive Food Items
max_price = 0.0
max_food = ""

for food_items in menu:
    price = menu[food_items]["price"]
    
    if price > max_price:
        max_price = price
        max_food = food_items
        
print("Most Expensive Menu Food Item is : ", max_food, "-", "Rs.", format(max_price, ".2f"))

# Food Items under 150

print("\n----- Food Items under Rs. 150 -----")

for food in menu:
    price = menu[food]["price"]
    if price <= 150:
        print(f"{food} - Rs. {price:.2f}")
# Out:
#  ----- Total Food Items in the Menu -----
# Total Menu Food Items :  10
# Available Menu Food Items :  8
# Most Expensive Menu Food Item is :  Butter Chicken - Rs. 320.00
#
# ----- Food Items under Rs. 150 -----
# Veg Soup - Rs. 120.00
# Garlic Naan - Rs. 40.00
# Gulab Jamun - Rs. 90.00
# Rasgulla - Rs. 80.00
# Ice Cream - Rs. 110.00

# %%
menu = {
    "Paneer Tikka":   {"category": "Starters",  "price": 180.0, "available": True},
    "Chicken Wings":  {"category": "Starters",  "price": 220.0, "available": False},
    "Veg Soup":       {"category": "Starters",  "price": 120.0, "available": True},
    "Butter Chicken": {"category": "Mains",     "price": 320.0, "available": True},
    "Dal Tadka":      {"category": "Mains",     "price": 180.0, "available": True},
    "Veg Biryani":    {"category": "Mains",     "price": 250.0, "available": True},
    "Garlic Naan":    {"category": "Mains",     "price":  40.0, "available": True},
    "Gulab Jamun":    {"category": "Desserts",  "price":  90.0, "available": True},
    "Rasgulla":       {"category": "Desserts",  "price":  80.0, "available": True},
    "Ice Cream":      {"category": "Desserts",  "price": 110.0, "available": False},
}

inventory = {
    "Paneer Tikka":   {"stock": 10, "reorder_level": 3},
    "Chicken Wings":  {"stock":  8, "reorder_level": 2},
    "Veg Soup":       {"stock": 15, "reorder_level": 5},
    "Butter Chicken": {"stock": 12, "reorder_level": 4},
    "Dal Tadka":      {"stock": 20, "reorder_level": 5},
    "Veg Biryani":    {"stock":  6, "reorder_level": 3},
    "Garlic Naan":    {"stock": 30, "reorder_level": 10},
    "Gulab Jamun":    {"stock":  5, "reorder_level": 2},
    "Rasgulla":       {"stock":  4, "reorder_level": 3},
    "Ice Cream":      {"stock":  7, "reorder_level": 4},
}

# TASK 2 — Cart Operations

cart = []

# Function to display cart
def show_cart():
    print("\nCurrent Cart:")
    if not cart:
        print("Cart is empty.")
    else:
        for item in cart:
            print(f"{item['item']} x{item['quantity']} (Rs.{item['price']})")

# Function to add item
def add_item(name, qty):
    if name not in menu:
        print(f"{name} not found in menu.")
        return

    if not menu[name]["available"]:
        print(f"{name} is currently unavailable.")
        return

    # check if already in cart
    for item in cart:
        if item["item"] == name:
            item["quantity"] += qty
            print(f"Updated quantity of {name} to {item['quantity']}")
            return

    # add new item
    cart.append({
        "item": name,
        "quantity": qty,
        "price": menu[name]["price"]
    })
    print(f"Added {name} x{qty} to cart.")


# Function to remove item
def remove_item(name):
    for item in cart:
        if item["item"] == name:
            cart.remove(item)
            print(f"{name} removed from cart.")
            return
    print(f"{name} not found in cart.")


# Function to update quantity
def update_quantity(name, qty):
    for item in cart:
        if item["item"] == name:
            item["quantity"] = qty
            print(f"{name} quantity updated to {qty}")
            return
    print(f"{name} not found in cart.")

# Simulation Steps
print("\n Simulating the costumer's request: ")

add_item("Paneer Tikka", 2)
show_cart()

add_item("Gulab Jamun", 1)
show_cart()

add_item("Paneer Tikka", 1)
show_cart()

add_item("Mystery Burger", 1)
show_cart()

add_item("Chicken Wings", 1)
show_cart()

remove_item("Gulab Jamun")
show_cart()


# Final Order Summary

print("\n----------- Order Summary -----------")

subtotal = 0

for item in cart:
    item_total = item["quantity"] * item["price"]
    subtotal += item_total
    print(f"{item['item']:<15} x{item['quantity']}    Rs.{item_total:.2f}")

print("---------------------------------------")

gst = subtotal * 0.05
total = subtotal + gst

print(f"Subtotal:                Rs.{subtotal:.2f}")
print(f"GST (5%):               Rs.{gst:.2f}")
print(f"Total Payable:          Rs.{total:.2f}")
print("----------------------------------------")
# Out:
#  Simulating the costumer's request:
# Added Paneer Tikka x2 to cart.
#
# Current Cart:
# Paneer Tikka x2 (Rs.180.0)
# Added Gulab Jamun x1 to cart.
#
# Current Cart:
# Paneer Tikka x2 (Rs.180.0)
# Gulab Jamun x1 (Rs.90.0)
# Updated quantity of Paneer Tikka to 3
#
# Current Cart:
# Paneer Tikka x3 (Rs.180.0)
# Gulab Jamun x1 (Rs.90.0)
# Mystery Burger not found in menu.
#
# Current Cart:
# Paneer Tikka x3 (Rs.180.0)
# Gulab Jamun x1 (Rs.90.0)
# Chicken Wings is currently unavailable.
#
# Current Cart:
# Paneer Tikka x3 (Rs.180.0)
# Gulab Jamun x1 (Rs.90.0)
# Gulab Jamun removed from cart.
#
# Current Cart:
# Paneer Tikka x3 (Rs.180.0)
#
# ----------- Order Summary -----------
# Paneer Tikka    x3    Rs.540.00
# ---------------------------------------
# Subtotal:                Rs.540.00
# GST (5%):               Rs.27.00
# Total Payable:          Rs.567.00
# ----------------------------------------

# %%
# ----- Task 3: Inventory tracker with Deep copy -----
menu = {
    "Paneer Tikka":   {"category": "Starters",  "price": 180.0, "available": True},
    "Chicken Wings":  {"category": "Starters",  "price": 220.0, "available": False},
    "Veg Soup":       {"category": "Starters",  "price": 120.0, "available": True},
    "Butter Chicken": {"category": "Mains",     "price": 320.0, "available": True},
    "Dal Tadka":      {"category": "Mains",     "price": 180.0, "available": True},
    "Veg Biryani":    {"category": "Mains",     "price": 250.0, "available": True},
    "Garlic Naan":    {"category": "Mains",     "price":  40.0, "available": True},
    "Gulab Jamun":    {"category": "Desserts",  "price":  90.0, "available": True},
    "Rasgulla":       {"category": "Desserts",  "price":  80.0, "available": True},
    "Ice Cream":      {"category": "Desserts",  "price": 110.0, "available": False},
}

inventory = {
    "Paneer Tikka":   {"stock": 10, "reorder_level": 3},
    "Chicken Wings":  {"stock":  8, "reorder_level": 2},
    "Veg Soup":       {"stock": 15, "reorder_level": 5},
    "Butter Chicken": {"stock": 12, "reorder_level": 4},
    "Dal Tadka":      {"stock": 20, "reorder_level": 5},
    "Veg Biryani":    {"stock":  6, "reorder_level": 3},
    "Garlic Naan":    {"stock": 30, "reorder_level": 10},
    "Gulab Jamun":    {"stock":  5, "reorder_level": 2},
    "Rasgulla":       {"stock":  4, "reorder_level": 3},
    "Ice Cream":      {"stock":  7, "reorder_level": 4},
}

sales_log = {
    "2025-01-01": [
        {"order_id": 1,  "items": ["Paneer Tikka", "Garlic Naan"],          "total": 220.0},
        {"order_id": 2,  "items": ["Gulab Jamun", "Veg Soup"],              "total": 210.0},
        {"order_id": 3,  "items": ["Butter Chicken", "Garlic Naan"],        "total": 360.0},
    ],
    "2025-01-02": [
        {"order_id": 4,  "items": ["Dal Tadka", "Garlic Naan"],             "total": 220.0},
        {"order_id": 5,  "items": ["Veg Biryani", "Gulab Jamun"],           "total": 340.0},
    ],
    "2025-01-03": [
        {"order_id": 6,  "items": ["Paneer Tikka", "Rasgulla"],             "total": 260.0},
        {"order_id": 7,  "items": ["Butter Chicken", "Veg Biryani"],        "total": 570.0},
        {"order_id": 8,  "items": ["Garlic Naan", "Gulab Jamun"],           "total": 130.0},
    ],
    "2025-01-04": [
        {"order_id": 9,  "items": ["Dal Tadka", "Garlic Naan", "Rasgulla"], "total": 300.0},
        {"order_id": 10, "items": ["Paneer Tikka", "Gulab Jamun"],          "total": 270.0},
    ],
}

# ----- Task 3: Inventory Check with Deep Copy -----
import copy

# Step 1: Deep copy inventory
inventory_backup = copy.deepcopy(inventory)
print("\n----- Checking Deep Copy -----")

# Step 2: Modify Original Inventory
inventory["Paneer Tikka"]["stock"] = 5
print("Modified inventory stock: ", inventory["Paneer Tikka"])
print("Backup inventory stock:", inventory_backup["Paneer Tikka"])

# Step 3: Restory inventory back to normal
inventory = copy.deepcopy(inventory_backup)
print("\nInventory restored successfully")

# Step 4: Reduce the stock based on cart
print("\n----- Updating inventory after order -----")

for item in cart:
    name = item["item"]
    qty = item["quantity"]
    
    if name in inventory:
        available_stock =  inventory[name]["stock"]
        
        if available_stock >= qty:
            inventory[name]["stock"] -= qty
            print(f"{name}: stock reduced by {qty}, remaining {inventory[name]['stock']}")
        else:
            print(f"Not enough stock for {name}. only{available_stock} is available.")
            inventory[name]["stock"] = 0
            
# Step 5: Re-order Alerts

print("\n----- Re-order Alerts -----")

for name, info in inventory.items():
    if info["stock"] <= info["reorder_level"]:
        print(f" Re-order Alert: {name} - Only {info['stock']} unit(s) left (reorder level: {info['reorder_level']})")
        
# Step 6: Final Check
print("\n----- Final Inventory vs Backup -----")

print("\nCurrent Inventory (after order): ")
for name, info in inventory.items():
    print(name, ":", info)
    
print("\nBackup Inventory (original data): ")
for name, info in inventory_backup.items():
    print(name, ":", info)
# Out:
# ----- Checking Deep Copy -----
# Modified inventory stock:  {'stock': 5, 'reorder_level': 3}
# Backup inventory stock: {'stock': 10, 'reorder_level': 3}
#
# Inventory restored successfully
#
# ----- Updating inventory after order -----
# Paneer Tikka: stock reduced by 3, remaining 7
#
# ----- Re-order Alerts -----
#
# ----- Final Inventory vs Backup -----
#
# Current Inventory (after order):
# Paneer Tikka : {'stock': 7, 'reorder_level': 3}
# Chicken Wings : {'stock': 8, 'reorder_level': 2}
# Veg Soup : {'stock': 15, 'reorder_level': 5}
# Butter Chicken : {'stock': 12, 'reorder_level': 4}
# Dal Tadka : {'stock': 20, 'reorder_level': 5}
# Veg Biryani : {'stock': 6, 'reorder_level': 3}
# Garlic Naan : {'stock': 30, 'reorder_level': 10}
# Gulab Jamun : {'stock': 5, 'reorder_level': 2}
# Rasgulla : {'stock': 4, 'reorder_level': 3}
# Ice Cream : {'stock': 7, 'reorder_level': 4}
#
# Backup Inventory (original data):
# Paneer Tikka : {'stock': 10, 'reorder_level': 3}
# ...

# %%
sales_log = {
    "2025-01-01": [
        {"order_id": 1,  "items": ["Paneer Tikka", "Garlic Naan"],          "total": 220.0},
        {"order_id": 2,  "items": ["Gulab Jamun", "Veg Soup"],              "total": 210.0},
        {"order_id": 3,  "items": ["Butter Chicken", "Garlic Naan"],        "total": 360.0},
    ],
    "2025-01-02": [
        {"order_id": 4,  "items": ["Dal Tadka", "Garlic Naan"],             "total": 220.0},
        {"order_id": 5,  "items": ["Veg Biryani", "Gulab Jamun"],           "total": 340.0},
    ],
    "2025-01-03": [
        {"order_id": 6,  "items": ["Paneer Tikka", "Rasgulla"],             "total": 260.0},
        {"order_id": 7,  "items": ["Butter Chicken", "Veg Biryani"],        "total": 570.0},
        {"order_id": 8,  "items": ["Garlic Naan", "Gulab Jamun"],           "total": 130.0},
    ],
    "2025-01-04": [
        {"order_id": 9,  "items": ["Dal Tadka", "Garlic Naan", "Rasgulla"], "total": 300.0},
        {"order_id": 10, "items": ["Paneer Tikka", "Gulab Jamun"],          "total": 270.0},
    ],
}

# Task 4: Daily Sales Log Analysis

print("\n----- Revenue Per Day -----")

# Step 1: Total Revenue Per Day
for date, orders in sales_log.items():
    total = 0
    for order in orders:
        total += order["total"]
    print(f"{date} : Rs.{total: .2f}")
    
# Step 2: Best-Selling Day
best_day = ""
highest = 0

for date, orders in sales_log.items():
    total = sum(order["total"] for order in orders)
    
    if total > highest:
        highest = total
        best_day = date
        
print(f"\nBest Selling Day: {best_day} - Rs. {highest: .2f}")

# Step 3: Most Ordered Item
item_count = {}

for orders in sales_log.values():
    for order in orders:
        for item in order["items"]:
            item_count[item] = item_count.get(item, 0) + 1

most_item = max(item_count, key=item_count.get)

print(f"\nMost Ordered Item is: {most_item}")

# Step 4: Add New Day

sales_log["2025-01-05"] = [
    {
        "order_id": 11,
        "items": ["Butter Chicken", "Gulab Jamun", "Garlic Naan"],
        "total": 490.0
        },
    {
        "order_id": 12,
        "items": ["Paneer Tikka", "Rasgulla"],
        "total": 260.0
        }
    ]
print("\n----- Updated Revenue Day -----")

for date, orders in sales_log.items():
    total = sum(order["total"] for order in orders)
    print(f"{date} : Rs.{total: .2f}")
    
# Recalculate The Best-Selling Day
best_day = ""
highest = 0

for date, orders in sales_log.items():
    total = sum(order["total"] for order in orders)
    
    if total > highest:
        highest = total
        best_day = date
        
print(f"\nUpdated Best Selling Day: {best_day} - Rs. {highest: .2f}")

# Step 5: Enumerate All Orders
print("\n----- All Orders -----")

all_orders = []

# Collect all orders with date
for date, orders in sales_log.items():
    for order in orders:
        all_orders.append((date, order))
        
# Enumerate
for i, (date, order) in enumerate(all_orders, start=1):
    items_str = ", ".join(order["items"])
    print(f"{i}. [{date}] Order #{order['order_id']} - Rs.{order['total']: .2f} - Items: {items_str}")
# Out:
# ----- Revenue Per Day -----
# 2025-01-01 : Rs. 790.00
# 2025-01-02 : Rs. 560.00
# 2025-01-03 : Rs. 960.00
# 2025-01-04 : Rs. 570.00
#
# Best Selling Day: 2025-01-03 - Rs.  960.00
#
# Most Ordered Item is: Garlic Naan
#
# ----- Updated Revenue Day -----
# 2025-01-01 : Rs. 790.00
# 2025-01-02 : Rs. 560.00
# 2025-01-03 : Rs. 960.00
# 2025-01-04 : Rs. 570.00
# 2025-01-05 : Rs. 750.00
#
# Updated Best Selling Day: 2025-01-03 - Rs.  960.00
#
# ----- All Orders -----
# 1. [2025-01-01] Order #1 - Rs. 220.00 - Items: Paneer Tikka, Garlic Naan
# 2. [2025-01-01] Order #2 - Rs. 210.00 - Items: Gulab Jamun, Veg Soup
# 3. [2025-01-01] Order #3 - Rs. 360.00 - Items: Butter Chicken, Garlic Naan
# 4. [2025-01-02] Order #4 - Rs. 220.00 - Items: Dal Tadka, Garlic Naan
# 5. [2025-01-02] Order #5 - Rs. 340.00 - Items: Veg Biryani, Gulab Jamun
# 6. [2025-01-03] Order #6 - Rs. 260.00 - Items: Paneer Tikka, Rasgulla
# 7. [2025-01-03] Order #7 - Rs. 570.00 - Items: Butter Chicken, Veg Biryani
# ...
